# %% [markdown]
# #Data ingestion

# %%
from langchain_core.documents import Document

# %%
doc=Document(
    page_content="this is the main text content I am using to create RAG",
    metadata={
        "source":"example.txt",
        "pages":1,
        "author":"Mohammed",
        "date_created":"2025-11-25"
    }
)
doc
# Out:
# Document(metadata={'source': 'example.txt', 'pages': 1, 'author': 'Mohammed', 'date_created': '2025-11-25'}, page_content='this is the main text content I am using to create RAG')

# %%
## Create a simple txt file
import os
os.makedirs("../data/text_files",exist_ok=True)

# %%
sample_texts={
    "../data/text_files/python_intro.txt":"""Python Programming Introduction

Python is a high-level, interpreted programming language known for its simplicity and readability.
Created by Guido van Rossum and first released in 1991, Python has become one of the most popular
programming languages in the world.

Key Features:
- Easy to learn and use
- Extensive standard library
- Cross-platform compatibility
- Strong community support

Python is widely used in web development, data science, artificial intelligence, and automation.""",
    
    "../data/text_files/machine_learning.txt": """Machine Learning Basics

Machine learning is a subset of artificial intelligence that enables systems to learn and improve
from experience without being explicitly programmed. It focuses on developing computer programs
that can access data and use it to learn for themselves.

Types of Machine Learning:
1. Supervised Learning: Learning with labeled data
2. Unsupervised Learning: Finding patterns in unlabeled data
3. Reinforcement Learning: Learning through rewards and penalties

Applications include image recognition, speech processing, and recommendation systems
    
    
    """

}

for filepath,content in sample_texts.items():
    with open(filepath,'w',encoding="utf-8") as f:
        f.write(content)

print("✅ Sample text files created!")
# Out:
# ✅ Sample text files created!

# %%
### TextLoader
# from langchain.document_loaders import TextLoader

from langchain_community.document_loaders import TextLoader

loader=TextLoader("../data/text_files/python_intro.txt",encoding="utf-8")
document=loader.load()
print(document)
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %%
### Directory Loader
from langchain_community.document_loaders import DirectoryLoader

## load all the text files from the directory
dir_loader=DirectoryLoader(
    "../data/text_files",
    glob="**/*.txt", ## Pattern to match files  
    loader_cls= TextLoader, ##loader class to use
    loader_kwargs={'encoding': 'utf-8'},
    show_progress=False

)

documents=dir_loader.load()
documents
# Out:
# [Document(metadata={'source': '..\\data\\text_files\\machine_learning.txt'}, page_content='Machine Learning Basics\n\nMachine learning is a subset of artificial intelligence that enables systems to learn and improve\nfrom experience without being explicitly programmed. It focuses on developing computer programs\nthat can access data and use it to learn for themselves.\n\nTypes of Machine Learning:\n1. Supervised Learning: Learning with labeled data\n2. Unsupervised Learning: Finding patterns in unlabeled data\n3. Reinforcement Learning: Learning through rewards and penalties\n\nApplications include image recognition, speech processing, and recommendation systems\n\n\n    '),
#  Document(metadata={'source': '..\\data\\text_files\\python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %%
from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader

## load all the text files from the directory
dir_loader=DirectoryLoader(
    "../data/pdf",
    glob="**/*.pdf", ## Pattern to match files  
    loader_cls= PyMuPDFLoader, ##loader class to use
    show_progress=False

)

pdf_documents=dir_loader.load()
pdf_documents
# Out:
# [Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2025-10-31T09:41:50+01:00', 'source': '..\\data\\pdf\\Employee Attire, Appearance  Hygiene - Orange Drugs Rev.pdf', 'file_path': '..\\data\\pdf\\Employee Attire, Appearance  Hygiene - Orange Drugs Rev.pdf', 'total_pages': 2, 'format': 'PDF 1.7', 'title': '', 'author': 'Francisca Iruolagbe', 'subject': '', 'keywords': '', 'moddate': '2025-10-31T09:41:50+01:00', 'trapped': '', 'modDate': "D:20251031094150+01'00'", 'creationDate': "D:20251031094150+01'00'", 'page': 0}, page_content='ORANGE GROUP EMPLOYEE ATTIRE, APPEARANCE & HYGIENE POLICY \n \nEffective Date: Immediate Effect \nApproved By: Management \nApplies To: All Employees  \n \nPurpose \n \nThe purpose of this policy is to establish clear standards for employee grooming and personal hygiene that \npromotes professionalism, health, safety, and a positive workplace image. Maintaining appropriate personal \nappearance and cleanliness reflects Orange Group’s commitment to excellence and a safe and comfortable \nworking environment for employees, customers, and visitors. \n \nScope  \n \nThis policy applies to all employees (any reference to employees include contract employees, Management \nTrainees, and interns), regardless of position or department, but subject to the standard requirement for \nemployees in production and warehouse operations with specific and stricter grooming and hygiene \nrequirements based on safety or regulatory standards. \n \nPolicy Statement \n \nAll employees are expected to maintain a high standard of personal cleanliness and grooming while on duty or \nrepresenting the company. Employees must be neat, well-groomed, and appropriately dressed in a manner \nconsistent with their respective job functions, safety requirements, and Orange Group’s professional image. \n \nUniforms/Business Attires \n \nEmployees must comply with departmental dress code standards as provided in the Employee Handbook as \nlisted below, ensuring uniforms are clean, pressed, and properly fitted. \ni. Traditional/native attires are not allowed except on management approval for specific company events. \nii. No outrageous coloured outfits are permitted.  \niii. No slippers are allowed to the office except on exceptional circumstances. \niv. Shoes should be worn. Neat sandals are allowed.  \nv. No micro-mini dresses or skirts.  \n \nMonday to Thursday dress code (strictly formal or business casual) -  \n i. Males: shirt and trousers (properly tucked in) suit and tie is optional.  \nii. Female: dresses, blouse/shirt and skirt/trouser, skirt/trouser suit (no jeans allowed).  \niii. Security: full uniform is expected. All factory/production/QC must be dressed smartly in a formal fashion \nat all times with a lab coat and head cap on.  \niv. Drivers and warehouse employees – business casual, e.g. shirts, trousers/jeans trousers. \nv. Production - Lab coat with the appropriate Personal Protective Equipment (PPE).  \nvi. Office shoes expected. No slippers, gladiator sandals, pam slippers or sports shoes are allowed.  \n \nFriday dress code (dress down) - \ni. Male: Company-branded T-shirts only and trousers/non-shredded jeans.  \nii. Female: Company-branded T-shirts only and trousers/skirts/non-shredded Jeans.  \n \nWhere uniforms are provided, employee shall always be dressed in the respective uniforms and to the standard \nrequired by Orange Group. If dress day is required, Orange Group branded outfits only should be worn. \n \nGeneral Hygiene and Grooming Standards \n \nNo employee shall have odour generally offensive to others when reporting to work. An offensive body odour \nmay result from a lack of good hygiene or from excessive application of fragrances, aftershaves or perfumes, \nor from any other cause. Therefore, employees’ must adhere to the following standards:'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2025-10-31T09:41:50+01:00', 'source': '..\\data\\pdf\\Employee Attire, Appearance  Hygiene - Orange Drugs Rev.pdf', 'file_path': '..\\data\\pdf\\Employee Attire, Appearance  Hygiene - Orange Drugs Rev.pdf', 'total_pages': 2, 'format': 'PDF 1.7', 'title': '', 'author': 'Francisca Iruolagbe', 'subject': '', 'keywords': '', 'moddate': '2025-10-31T09:41:50+01:00', 'trapped': '', 'modDate': "D:20251031094150+01'00'", 'creationDate': "D:20251031094150+01'00'", 'page': 1}, page_content='• Maintain daily personal cleanliness. A regular bathing at least twice daily and the use of deodorant or \nantiperspirant is a recommended good practice \n• Ensure oral hygiene through regular brushing, flossing, and dental care. Employees are encouraged to \nbrush teeth at least twice daily and rinse mouth thoroughly after meals, either by using mouthwash or \nwater. \n• Keep hair clean, neatly styled, and away from the face (tied back when required for safety or hygiene \nreasons). \n• Beards and moustaches must be neatly trimmed and maintained and moustaches are not allowed to grow \nbeyond the upper lip;  \n• Maintain clean and trimmed fingernails (nails must be of an acceptable and reasonable length). \n• Makeup should be moderate and not distracting, and jewelry and accessories must be conservative. \n• Avoid strong body odours, including excessive and overpowering perfumes, cologne, or scented lotions. \n• Wear clean clothes or uniforms each day and ensure shoes are clean and in good condition. \n• Comply with the company’s guidelines on the use of personal protective equipment (PPE) and maintain it \nin clean condition. \n \n Health and Hygiene Practices \n \n• Employees must report any medical condition or skin infection that could pose a hygiene or safety risk in \nthe workplace. \n• Frequent handwashing, especially after using restrooms, eating or handling materials is mandatory. \n• Employees should practice good respiratory etiquette—covering the mouth and nose when sneezing or \ncoughing. \n \nNon-Compliance  \n \nDeparture from appropriate grooming, hygiene and attire standards will result in employee counselling and \nmay attract progressive disciplinary actions/measures: \n• A verbal or written warning for first-time or minor violations. \n• Temporary removal from duty until grooming or hygiene standards are corrected. \n• Disciplinary action up to and including possible termination for repeated or severe breaches, especially \nthose affecting safety, health, or the company’s reputation. \n \nRoles and Responsibilities \n \n• Employees must adhere to this policy and maintain the company’s attire, grooming and hygiene standards. \n• Managers and supervisors are responsible for monitoring compliance and addressing any breaches \npromptly and respectfully. \n• The Human Resources department is to enforce the Policy in a fair and consistent manner. \n \nReview and Revision \n \nThis Policy may be reviewed periodically and updated as needed, to ensure alignment with company values, \nindustry standards, and legal requirements. \n \nAll employees are required to sign below to confirm that they have read, understood, and agreed to comply \nwith the Workplace Loitering Policy. \n \n \nEmployee Name: ………………………………………………. \n \n \nSignature: ……………………………………….. Date: …………………………………'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2025-11-06T16:05:49+01:00', 'source': '..\\data\\pdf\\Memo - HR Open Door Policy Guideline to All Staff.pdf', 'file_path': '..\\data\\pdf\\Memo - HR Open Door Policy Guideline to All Staff.pdf', 'total_pages': 1, 'format': 'PDF 1.7', 'title': '', 'author': 'Francisca Iruolagbe', 'subject': '', 'keywords': '', 'moddate': '2025-11-06T16:05:49+01:00', 'trapped': '', 'modDate': "D:20251106160549+01'00'", 'creationDate': "D:20251106160549+01'00'", 'page': 0}, page_content='MEMORANDUM  \n \nHR/001/102025 \n \nTo: All Employees, Management Trainees and Contract Staff \n \nCc: GMs and BDD \n \nFrom: HR \n \nDate: 3 November 2025 \n \nSubject: Human Resources (HR) Open Door Policy Guideline \n \nAt Orange Group, the importance of effective communication between employees and management is recognized and \nforms the basis of a sound relationship and a positive and productive work environment. This Policy is reflected in the \nGroup’s “Open Door” philosophy, as detailed in the Employee Handbook, and the HR department is tasked with the \nresponsibility of ensuring the success and effectiveness of the Policy. \nPlease be assured that the HR department will always be available to support and assist employees to address their \nqueries and concerns, and in meeting with this responsibility, it kindly asks that all employees respect the HR office as \na productive workspace, where sensitive employee matters are treated and confidential records stored, and accordingly \nsome measure of quiet and privacy is required to boost focus and productivity, and maintain confidentiality. To \nachieve this, the following guidelines have been put in place to ensure a committed and effective open-door practice: \n1. HR Physical Visit Hours –  \nWhere there is need for an employee to physically visit the HR office for non-urgent personal HR related queries, \ncomplaints or concerns, this may be done on Thursdays and Fridays only, between 10.00am and 4.00pm. \n2. Other Days (outside Thursdays and Fridays) –  \nOn other days, all queries, complaints and concerns should be handwritten or printed and placed in the designated HR \nCompliant Box/Container by the foot of main building staircase and the same will be treated within forty-Eight (48) \nhours of submission.  \nNote: For urgent and sensitive employee matters that require immediate attention, the HR office is open daily \nfrom Monday to Friday for physical visits, and employees are advised to visit only when absolutely urgent.     \n3. Email Correspondence -   \n \nEmployees may also reach out to HR via email, using the HR.office@orangegroups.ng email address, as this remains \nan effective channel of communication for all HR-related matters. Employees may submit written requests, seek \nclarifications and address any issue that require prompt attention or documentation. HR will monitor the email \nregularly to ensure timely and efficient response to all queries and complaints raised. \n4. HR Phone and Intercom Line - \nTo further enhance accessibility, a mobile call can be placed directly to the concerned HR personnel or employees \nmay contact HR via the office telephone Intercom from their respective offices for matters that may be resolved \nwithout the need for physical presence, or that does not require written communication. \nThis guideline is in line with Section 4.8 of the company’s Employee Handbook and it is to ensure that the HR \nDepartment remains open and committed to treating employees queries and concerns, and be able to receive ideas and \nfeedback in order to promote open communication, while maintaining productivity and confidentiality at the HR. \nThank you for your understanding.'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2025-10-17T12:41:21+01:00', 'source': '..\\data\\pdf\\Orange Group Workplace Loitering Policy.pdf', 'file_path': '..\\data\\pdf\\Orange Group Workplace Loitering Policy.pdf', 'total_pages': 2, 'format': 'PDF 1.7', 'title': '', 'author': 'Francisca Iruolagbe', 'subject': '', 'keywords': '', 'moddate': '2025-10-17T12:41:21+01:00', 'trapped': '', 'modDate': "D:20251017124121+01'00'", 'creationDate': "D:20251017124121+01'00'", 'page': 0}, page_content='ORANGE GROUP WORKPLACE LOITERING POLICY \n \nEffective Date: Immediate Effect \nApproved By: Management \nApplies To: All Employees, Contractors, and Visitors. \n \n1. Purpose \n \nThe Workplace Loitering Policy (hereafter referred to as “this or the Policy”) aims to maintain a \nprofessional, safe and productive work environment by outlining acceptable standards of conduct \nconcerning loitering within the workplace. The Policy is to ensure that all employees remain focused \non their assigned duties, minimize disruptions to workflow, and contribute to maintain workplace \nsafety and security and the protection of company property. \n \n2. Scope \n \n2.1. This policy applies to all employees, contractors/vendors, and visitors within the company \npremises, including office spaces, production areas, warehouses, corridors, parking lots, and \ncompany provided facilities. \n \n2.2. Reference to employees includes full time and contract employees, and management trainees \nand interns.  \n \n3. Definition of Loitering \n \nLoitering refers to the act of lingering, idling, or remaining in an area of the workplace without \nperforming assigned duties or without a legitimate work-related purpose, or beyond authorized \nworking hours. This includes: \n \n3.1. Congregating in hallways or break areas for extended periods; \n \n3.2. visiting other departments unnecessarily and without a work related purpose; \n \n3.3. being in restricted zones without permission; \n \n3.4. sitting or napping in the staff canteen before official lunch break time and delaying return from \nbreaks or lunch periods; and \n \n3.5. remaining in work areas after clocking out without reasons or legitimate work-related purpose. \n \n4. Policy Statement \n \n4.1. Employees are encouraged to arrive at work few minutes before contracted or approved \ncommencement time of work to allow them attend to personal need-related matters, including \ntaking breakfast, and enough time to prepare for work proper. \n \n4.2. Employees are expected to remain at their designated workstations during working hours and \nrespect their colleagues’ focus and attentiveness to work;  \n \n4.3. Employees are to avoid loitering in restricted areas including server rooms and warehouses, and \nleave the premises promptly after their work time unless authorized otherwise;'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2025-10-17T12:41:21+01:00', 'source': '..\\data\\pdf\\Orange Group Workplace Loitering Policy.pdf', 'file_path': '..\\data\\pdf\\Orange Group Workplace Loitering Policy.pdf', 'total_pages': 2, 'format': 'PDF 1.7', 'title': '', 'author': 'Francisca Iruolagbe', 'subject': '', 'keywords': '', 'moddate': '2025-10-17T12:41:21+01:00', 'trapped': '', 'modDate': "D:20251017124121+01'00'", 'creationDate': "D:20251017124121+01'00'", 'page': 1}, page_content='5. Exceptions \n \nAcceptable exceptions to loitering include authorized breaks (lunch and toilet runs), waiting for \nofficial transport, attending approved company activities, or being present for emergencies. \n \n6. Monitoring and Enforcement \n \nSupervisors may monitor offices and office common areas, while security personnel will monitor the \ncompany premises and surroundings to ensure compliance. \n \n7. Disciplinary Actions \n \nThis Policy is subject to, and shall be read together with codes of conducts and policies provided in \nthe Orange Drug Employee handbook as it relates to attendance and punctuality and eemployees \ndisciplinary procedures. Consequently, disciplinary actions for breach of this Policy shall \nprogressively apply as follows: \n \n7.1. Verbal warning and counselling for first infraction; \n \n7.2. Written warning to be documented in employee’s file for a repeat infraction; \n \n7.3. Final written warning or suspension for consistent infractions; and  \n \n7.4. Termination of employment for continued non-compliance. \n \n8. Roles and Responsibilities \n \n8.1. Employees are to comply with and report violations. \n \n8.2. Supervisors are to enforce the policy and document incidents. \n \n8.3. The Human Resources department is to maintain records and oversee disciplinary process. \n \n8.4. The company security is to monitor and report unauthorized presence around the company \npremises to management. \n \n9. Review and Amendments \n \nThis policy will be reviewed periodically by the Human Resources department to ensure its \neffectiveness and enforcements and any updates will be communicated to all employees in writing. \n \nAll employees are required to sign below to confirm that they have read, understood, and agreed to \ncomply with the Workplace Loitering Policy. \n \n \nEmployee Name: ………………………………………………. \n \n \nSignature: ……………………………………….. Date: …………………………………')]

# %%
type(pdf_documents[0])
# Out:
# langchain_core.documents.base.Document
